# %% [markdown]
# <a href="https://colab.research.google.com/github/Phaneendra-S/BTP/blob/main/code1_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
urldata=pd.read_csv("data - Copy.csv")

# urldata1=pd.DataFrame(urldata,)

# %%
urldata.head()
# Out:
#    sno                                                url  label
# 0    1  nobell.it/70ffb52d079109dca5664cce6f317373782/...      1
# 1    2  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...      1
# 2    3  serviciosbys.com/paypal.cgi.bin.get-into.herf....      1
# 3    4  mail.printakid.com/www.online.americanexpress....      1
# 4    5  thewhiskeydregs.com/wp-content/themes/widescre...      1

# %%
print("Percent Of Malicious URLs:{:.2f} %".format(len(urldata[urldata['label']==0.0])/len(urldata['label'])*100))
print("Percent Of Benign URLs:{:.2f} %".format(len(urldata[urldata['label']==1.0])/len(urldata['label'])*100))
urldata.info()
# Out:
# Percent Of Malicious URLs:50.06 %
# Percent Of Benign URLs:49.94 %
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95911 entries, 0 to 95910
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sno     95911 non-null  int64
#  1   url     95911 non-null  object
#  2   label   95911 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 2.2+ MB

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='label',data=urldata)
plt.title("Count Of URLs",fontsize=20)
plt.xlabel("Type Of URLs",fontsize=18)
plt.ylabel("Number Of URLs",fontsize=18)
# Out:
# Text(0, 0.5, 'Number Of URLs')

# %% [markdown]
# Classifiers And Feature Extraction

# %%
# !pip install tld
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tld
#   Downloading tld-0.13-py2.py3-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.8/263.8 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: tld
# Successfully installed tld-0.13

# %%
from urllib.parse import urlparse
from tld import get_tld
import os
import os.path

# %%
urldata['url_length'] = urldata['url'].apply(lambda i: len(str(i)))
urldata['hostname_length'] = urldata['url'].apply(lambda i: len(urlparse(i).netloc))

# %%
urldata['path_length'] = urldata['url'].apply(lambda i: len(urlparse(i).path))
def fd_length(url):
    urlpath= urlparse(url).path
    try:
        return len(urlpath.split('/')[1])
    except:
        return 0

urldata['fd_length'] = urldata['url'].apply(lambda i: fd_length(i))

urldata['tld'] = urldata['url'].apply(lambda i: get_tld(i,fail_silently=True))
def tld_length(tld):
    try:
        return len(tld)
    except:
        return -1

urldata['tld_length'] = urldata['tld'].apply(lambda i: tld_length(i))

# %%
urldata['count-'] = urldata['url'].apply(lambda i: i.count('-'))
urldata['count@'] = urldata['url'].apply(lambda i: i.count('@'))
urldata['count?'] = urldata['url'].apply(lambda i: i.count('?'))
urldata['count%'] = urldata['url'].apply(lambda i: i.count('%'))
urldata['count.'] = urldata['url'].apply(lambda i: i.count('.'))
urldata['count='] = urldata['url'].apply(lambda i: i.count('='))
urldata['count-http'] = urldata['url'].apply(lambda i : i.count('http'))
urldata['count-https'] = urldata['url'].apply(lambda i : i.count('https'))
urldata['count-www'] = urldata['url'].apply(lambda i: i.count('www'))

# %%
def digit_count(url):
    digits = 0
    for i in url:
        if i.isnumeric():
            digits = digits + 1
    return digits
urldata['count-digits']= urldata['url'].apply(lambda i: digit_count(i))

def letter_count(url):
    letters = 0
    for i in url:
        if i.isalpha():
            letters = letters + 1
    return letters
urldata['count-letters']= urldata['url'].apply(lambda i: letter_count(i))

def no_of_dir(url):
    urldir = urlparse(url).path
    return urldir.count('/')
urldata['count_dir'] = urldata['url'].apply(lambda i: no_of_dir(i))

# %%
# urldata.drop()
# urldata.head()
urldata.tail()
# urldata.isnull().mean()
# urldata.isna().mean()
# Out:
#          sno                                            url  label  \
# 95906  95907        xbox360.ign.com/objects/850/850402.html      0
# 95907  95908   games.teamxbox.com/xbox-360/1860/Dead-Space/      0
# 95908  95909     www.gamespot.com/xbox360/action/deadspace/      0
# 95909  95910  en.wikipedia.org/wiki/Dead_Space_(video_game)      0
# 95910  95911      www.angelfire.com/goth/devilmaycrytonite/      0
#
#        url_length  hostname_length  path_length  fd_length   tld  tld_length  \
# 95906          39                0           39          7  None          -1
# 95907          44                0           44          8  None          -1
# 95908          42                0           42          7  None          -1
# 95909          45                0           45          4  None          -1
# 95910          41                0           41          4  None          -1
#
#        count-  ...  count?  count%  count.  count=  count-http  count-https  \
# 95906       0  ...       0       0       3       0           0            0
# 95907       2  ...       0       0       2       0           0            0
# 95908       0  ...       0       0       2       0           0            0
# 95909       0  ...       0       0       2       0           0            0
# 95910       0  ...       0       0       2       0           0            0
#
#        count-www  count-digits  count-letters  count_dir
# 95906          0            12             21          3
# 95907          0             7             29          4
# 95908          1             3             33          4
# 95909          0             0             36          2
# 95910          1             0             36          3
#
# [5 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier

# %%
x = urldata[['url_length', 'hostname_length',
       'path_length', 'fd_length', 'count-', 'count@', 'count?',
       'count%', 'count.', 'count=', 'count-http','count-https', 'count-www', 'count-digits',
       'count-letters', 'count_dir']]
y = urldata['label']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
# x_train.head(3)
# x_test.head(3)
# y_train.head(3)
# y_test.head(3)

# %%
 # Create a logistic regression classifier
# log_model = LogisticRegression()

# Create a decision tree classifier
dt_model = DecisionTreeClassifier()

# Create a support vector machine classifier
svc_model = SVC()

# Create a random forest classifier
rfc_model = RandomForestClassifier()

# Initialize the LGBMClassifier
lgbm = LGBMClassifier(
    boosting_type='gbdt',         # Gradient boosting algorithm
    n_estimators=100,             # Number of trees to fit
    learning_rate=0.1,            # Learning rate for gradient boosting
    num_leaves=31,                # Number of leaves for each tree
    objective='binary',           # Binary classification problem
    random_state=42               # For reproducibility
)

# Initialize the AdaBoostClassifier
adaboost = AdaBoostClassifier(
    n_estimators=100,     # Number of trees to fit
    learning_rate=0.1,    # Learning rate for the weights update
    random_state=42       # For reproducibility
)

# Initialize the XGBClassifier
xgb = XGBClassifier(
    objective='binary:logistic',  # Binary classification problem
    n_estimators=100,             # Number of trees to fit
    learning_rate=0.1,            # Learning rate for gradient boosting
    max_depth=3,                  # Maximum depth of each tree
    random_state=42               # For reproducibility
)

# Train the classifiers on the training set
dt_model.fit(x_train, y_train)
svc_model.fit(x_train, y_train)
# log_model.fit(x_train, y_train)
rfc_model.fit(x_train, y_train)
lgbm.fit(x_train, y_train)
adaboost.fit(x_train, y_train)
xgb.fit(x_train, y_train)

# Evaluate the classifiers on the testing set
dt_predictions = dt_model.predict(x_test)
svc_predictions = svc_model.predict(x_test)
# log_predictions = log_model.predict(x_test)
rfc_predictions = rfc_model.predict(x_test)
lgbm_predictions = lgbm.predict(x_test)
adaboost_predictions = adaboost.predict(x_test)
xgb_predictions = xgb.predict(x_test)
                                    
# Print the accuracy scores
print("Decision tree accuracy:", accuracy_score(y_test, dt_predictions))
print("Support vector machine accuracy:", accuracy_score(y_test, svc_predictions))
# print("Logistic regression accuracy:", accuracy_score(y_test, log_predictions))
print("Random forest accuracy:", accuracy_score(y_test, rfc_predictions))
print("LGBM classifier accuracy:", accuracy_score(y_test, lgbm_predictions))
print("AdaBoost classifier accuracy:", accuracy_score(y_test, adaboost_predictions))
print("XGBoost classifier accuracy:", accuracy_score(y_test, xgb_predictions))
# Out:
# Decision tree accuracy: 0.8641481893375964
# Support vector machine accuracy: 0.7794536734552027
# Random forest accuracy: 0.8803433655383333
# LGBM classifier accuracy: 0.8793355112254119
# AdaBoost classifier accuracy: 0.8198373531660527
# XGBoost classifier accuracy: 0.8496559393897268

# %%
from keras.models import Sequential
from keras.layers import Dense

# Convert the data to numpy arrays
X_train = np.array(x_train)
y_train = np.array(y_train)
X_test = np.array(x_test)
y_test = np.array(y_test)

# Define the architecture of the neural network
model = Sequential()
model.add(Dense(units=16, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=1)

# Make predictions on the testing data
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)

print("Neural Networks accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Epoch 1/150
# 2099/2099 [==============================] - 11s 3ms/step - loss: 0.5535 - accuracy: 0.7537
# Epoch 2/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.4424 - accuracy: 0.7841
# Epoch 3/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.4336 - accuracy: 0.7876
# Epoch 4/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.4259 - accuracy: 0.7939
# Epoch 5/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.4186 - accuracy: 0.7998
# Epoch 6/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.4141 - accuracy: 0.8033
# Epoch 7/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.4108 - accuracy: 0.8068
# Epoch 8/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.4081 - accuracy: 0.8081
# Epoch 9/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.4061 - accuracy: 0.8103
# Epoch 10/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.4037 - accuracy: 0.8120
# Epoch 11/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.4030 - accuracy: 0.8136
# Epoch 12/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.4018 - accuracy: 0.8130
# Epoch 13/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3992 - accuracy: 0.8154
# Epoch 14/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3973 - accuracy: 0.8158
# Epoch 15/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3977 - accuracy: 0.8147
# Epoch 16/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3928 - accuracy: 0.8186
# Epoch 17/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3921 - accuracy: 0.8170
# Epoch 18/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3892 - accuracy: 0.8177
# Epoch 19/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3884 - accuracy: 0.8180
# Epoch 20/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3867 - accuracy: 0.8190
# Epoch 21/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3860 - accuracy: 0.8199
# Epoch 22/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3851 - accuracy: 0.8188
# Epoch 23/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3830 - accuracy: 0.8204
# Epoch 24/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3841 - accuracy: 0.8189
# Epoch 25/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3816 - accuracy: 0.8208
# Epoch 26/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3813 - accuracy: 0.8205
# Epoch 27/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3807 - accuracy: 0.8208
# Epoch 28/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3792 - accuracy: 0.8212
# Epoch 29/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3784 - accuracy: 0.8207
# Epoch 30/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3771 - accuracy: 0.8227
# Epoch 31/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3756 - accuracy: 0.8237
# Epoch 32/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3740 - accuracy: 0.8243
# Epoch 33/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3732 - accuracy: 0.8242
# Epoch 34/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3711 - accuracy: 0.8270
# Epoch 35/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3706 - accuracy: 0.8277
# Epoch 36/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3702 - accuracy: 0.8271
# Epoch 37/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3683 - accuracy: 0.8292
# Epoch 38/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3670 - accuracy: 0.8296
# Epoch 39/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3666 - accuracy: 0.8297
# Epoch 40/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3661 - accuracy: 0.8304
# Epoch 41/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3653 - accuracy: 0.8319
# Epoch 42/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3640 - accuracy: 0.8326
# Epoch 43/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3636 - accuracy: 0.8324
# Epoch 44/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3610 - accuracy: 0.8327
# Epoch 45/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3604 - accuracy: 0.8332
# Epoch 46/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3597 - accuracy: 0.8331
# Epoch 47/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3563 - accuracy: 0.8364
# Epoch 48/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3559 - accuracy: 0.8365
# Epoch 49/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3559 - accuracy: 0.8372
# Epoch 50/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3547 - accuracy: 0.8369
# Epoch 51/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3545 - accuracy: 0.8367
# Epoch 52/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3534 - accuracy: 0.8378
# Epoch 53/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3528 - accuracy: 0.8384
# Epoch 54/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3518 - accuracy: 0.8389
# Epoch 55/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3536 - accuracy: 0.8378
# Epoch 56/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3511 - accuracy: 0.8384
# Epoch 57/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3517 - accuracy: 0.8392
# Epoch 58/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3516 - accuracy: 0.8391
# Epoch 59/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3506 - accuracy: 0.8401
# Epoch 60/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3522 - accuracy: 0.8382
# Epoch 61/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3505 - accuracy: 0.8395
# Epoch 62/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3496 - accuracy: 0.8394
# Epoch 63/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3492 - accuracy: 0.8397
# Epoch 64/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3493 - accuracy: 0.8408
# Epoch 65/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3496 - accuracy: 0.8403
# Epoch 66/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3501 - accuracy: 0.8401
# Epoch 67/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3494 - accuracy: 0.8412
# Epoch 68/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3481 - accuracy: 0.8411
# Epoch 69/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3496 - accuracy: 0.8414
# Epoch 70/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3491 - accuracy: 0.8416
# Epoch 71/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3483 - accuracy: 0.8424
# Epoch 72/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3479 - accuracy: 0.8430
# Epoch 73/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3481 - accuracy: 0.8431
# Epoch 74/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3476 - accuracy: 0.8419
# Epoch 75/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3471 - accuracy: 0.8428
# Epoch 76/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3480 - accuracy: 0.8420
# Epoch 77/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3472 - accuracy: 0.8434
# Epoch 78/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3462 - accuracy: 0.8418
# Epoch 79/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3461 - accuracy: 0.8429
# Epoch 80/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3470 - accuracy: 0.8426
# Epoch 81/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3469 - accuracy: 0.8426
# Epoch 82/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3472 - accuracy: 0.8430
# Epoch 83/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3464 - accuracy: 0.8429
# Epoch 84/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3469 - accuracy: 0.8430
# Epoch 85/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3460 - accuracy: 0.8436
# Epoch 86/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3457 - accuracy: 0.8428
# Epoch 87/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3463 - accuracy: 0.8441
# Epoch 88/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3456 - accuracy: 0.8437
# Epoch 89/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3453 - accuracy: 0.8434
# Epoch 90/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3468 - accuracy: 0.8428
# Epoch 91/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3448 - accuracy: 0.8452
# Epoch 92/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3448 - accuracy: 0.8443
# Epoch 93/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3453 - accuracy: 0.8449
# Epoch 94/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3445 - accuracy: 0.8443
# Epoch 95/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3446 - accuracy: 0.8442
# Epoch 96/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3443 - accuracy: 0.8437
# Epoch 97/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3443 - accuracy: 0.8448
# Epoch 98/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3449 - accuracy: 0.8443
# Epoch 99/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3442 - accuracy: 0.8459
# Epoch 100/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3440 - accuracy: 0.8458
# Epoch 101/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3453 - accuracy: 0.8443
# Epoch 102/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3437 - accuracy: 0.8458
# Epoch 103/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3440 - accuracy: 0.8446
# Epoch 104/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3433 - accuracy: 0.8453
# Epoch 105/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3433 - accuracy: 0.8455
# Epoch 106/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3421 - accuracy: 0.8455
# Epoch 107/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3419 - accuracy: 0.8464
# Epoch 108/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3408 - accuracy: 0.8478
# Epoch 109/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3417 - accuracy: 0.8463
# Epoch 110/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3420 - accuracy: 0.8466
# Epoch 111/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3410 - accuracy: 0.8471
# Epoch 112/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3414 - accuracy: 0.8456
# Epoch 113/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3412 - accuracy: 0.8462
# Epoch 114/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3416 - accuracy: 0.8458
# Epoch 115/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3413 - accuracy: 0.8465
# Epoch 116/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3410 - accuracy: 0.8473
# Epoch 117/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3403 - accuracy: 0.8465
# Epoch 118/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3410 - accuracy: 0.8467
# Epoch 119/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3398 - accuracy: 0.8472
# Epoch 120/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3415 - accuracy: 0.8456
# Epoch 121/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3401 - accuracy: 0.8471
# Epoch 122/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3401 - accuracy: 0.8465
# Epoch 123/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3404 - accuracy: 0.8459
# Epoch 124/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3395 - accuracy: 0.8473
# Epoch 125/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3390 - accuracy: 0.8482
# Epoch 126/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3395 - accuracy: 0.8463
# Epoch 127/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3401 - accuracy: 0.8462
# Epoch 128/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3404 - accuracy: 0.8462
# Epoch 129/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3401 - accuracy: 0.8467
# Epoch 130/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3391 - accuracy: 0.8476
# Epoch 131/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3393 - accuracy: 0.8464
# Epoch 132/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3392 - accuracy: 0.8468
# Epoch 133/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3376 - accuracy: 0.8485
# Epoch 134/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3394 - accuracy: 0.8477
# Epoch 135/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3384 - accuracy: 0.8464
# Epoch 136/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3383 - accuracy: 0.8478
# Epoch 137/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3377 - accuracy: 0.8483
# Epoch 138/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3381 - accuracy: 0.8478
# Epoch 139/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3380 - accuracy: 0.8471
# Epoch 140/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3381 - accuracy: 0.8475
# Epoch 141/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3372 - accuracy: 0.8476
# Epoch 142/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3373 - accuracy: 0.8479
# Epoch 143/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3379 - accuracy: 0.8475
# Epoch 144/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3370 - accuracy: 0.8491
# Epoch 145/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3376 - accuracy: 0.8477
# Epoch 146/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3362 - accuracy: 0.8493
# Epoch 147/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3369 - accuracy: 0.8492
# Epoch 148/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3363 - accuracy: 0.8495
# Epoch 149/150
# 2099/2099 [==============================] - 7s 3ms/step - loss: 0.3373 - accuracy: 0.8492
# Epoch 150/150
# 2099/2099 [==============================] - 6s 3ms/step - loss: 0.3361 - accuracy: 0.8487
# 900/900 [==============================] - 1s 1ms/step
# Neural Networks accuracy: 0.8439911030791687

# %%
# import pandas as pd
# import numpy as np
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
# from sklearn.model_selection import train_test_split

# # Load the data
# data = urldata

# # Split the data into input features and target variable
# x = data.drop(labels=["label"], axis=1)
# y = data["label"]

# # Normalize the data
# # x = x / 255.0

# # Reshape the data for use in a CNN
# x = x.values.reshape(-1, 28, 28, 1)

# # Split the data into training and testing sets
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# # Define the CNN model
# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 3), activation="relu", input_shape=(28, 28, 1)))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(128, activation="relu"))
# model.add(Dropout(0.5))
# model.add(Dense(10, activation="softmax"))

# # Compile the model
# model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# # Fit the model to the training data
# model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.1)

# # Evaluate the model on the testing data
# score = model.evaluate(x_test, y_test, verbose=0)
# print("Test loss:", score[0])
# print("Test accuracy:", score[1])

# # Make predictions on the test data
# predictions = model.predict(x_test)

# # Convert the predictions to class labels
# labels = np.argmax(predictions, axis=1)

# # Print the confusion matrix
# from sklearn.metrics import confusion_matrix
# conf_matrix = confusion_matrix(y_test, labels)
# print(conf_matrix)

# %%
# Compute the confusion matrix for lgbm
cm_lgbm = confusion_matrix(y_test, lgbm_predictions)

# Print the confusion matrix as a heatmap
sns.heatmap(cm_lgbm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Compute the confusion matrix for lgbm
cm_rfc = confusion_matrix(y_test, rfc_predictions)

# Print the confusion matrix as a heatmap
sns.heatmap(cm_rfc, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
#cross validation for LGBM Classifier
from sklearn.model_selection import cross_val_score,KFold
X=x_train
Y=y_train
crossval_lgbm=LGBMClassifier()
kf=KFold(n_splits=10)
score=cross_val_score(crossval_lgbm,X,Y,cv=kf)
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))
# Out:
# Cross Validation Scores are [0.88188859 0.8728031  0.88427167 0.87414358 0.87965445 0.8798034
#  0.87890974 0.88261582 0.88723373 0.87561448]
# Average Cross Validation score :0.8796938555857169

# %%
#cross validation for RF Classifier
from sklearn.model_selection import cross_val_score,KFold
X=x_train
Y=y_train
crossval_rfc=RandomForestClassifier()
kf=KFold(n_splits=10)
score=cross_val_score(crossval_rfc,X,Y,cv=kf)
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))
# Out:
# Cross Validation Scores are [0.87712243 0.87533512 0.88129282 0.87131367 0.87682455 0.87429252
#  0.87682455 0.87829584 0.8864889  0.87650827]
# Average Cross Validation score :0.8774298673371099
